# %%
import huggingface_hub
huggingface_hub.notebook_login()
# Out:
# Token is valid.
# Your token has been saved in your configured git credential helpers (store).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %% [markdown]
# ### Data Processing

# %%
import os
import cv2
import glob
import json
import torch
import numpy as np
import pandas as pd
from typing import *
from PIL import Image
import pybboxes as pbx
from shutil import copyfile
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from matplotlib import animation, rc

rc('animation', html='jshtml')
pd.set_option('display.max_columns', None)
Image.MAX_IMAGE_PIXELS = None
os.environ['CUDA_VISIBLE_DEVICES'] = '1'
device = torch.cuda.is_available()
print (device)
# Out:
# False

# %%
# %%capture
# !git lfs install
# !git clone https://huggingface.co/datasets/datadrivenscience/ship-detection
''' #Using datasets library
from datasets import load_dataset
data = load_dataset("datadrivenscience/ship-detection") '''

# %%
# Define data directories
ROOT_DIR = "/content/ship-detection"
train_dir = os.path.join(ROOT_DIR, 'train')
train_imgs = glob.glob(train_dir+'/*.png')

test_dir = os.path.join(ROOT_DIR, 'test')
test_imgs = glob.glob(test_dir+'/*.png')

# %%
# convert image metadata to dataframe for easy manipulations

train_metadata = os.path.join(train_dir, 'metadata.jsonl') 
test_metadata = os.path.join(test_dir, 'metadata.jsonl')

with open(train_metadata, 'r+') as j_files:
  j_list = list(j_files)
  
bboxes = []
filename = []
categories = []

for j_fle in j_list:
  rslt = json.loads(j_fle)

  bboxes.append(rslt['objects']['bbox'])
  filename.append(rslt['file_name'])
  categories.append(rslt['objects']['categories'])


train_df = pd.DataFrame(
    {
        "filenames": filename,
        "bboxes": bboxes,
        "categories": categories,
    })

train_df = train_df.explode(['bboxes', 'categories']).reset_index(drop=True)
train_df.head()
# Out:
#   filenames                    bboxes categories
# 0     0.png  [6690, 3599, 7164, 3850]          0
# 1     0.png  [6772, 3386, 7039, 3546]          0
# 2     0.png  [6705, 3291, 7060, 3485]          0
# 3     0.png  [6230, 3442, 6597, 3647]          0
# 4     0.png    [5501, 790, 5552, 868]          0

# %%
# all the images doesn't have a unique size, 
## tghrtere will be a need for reshape
# NO Need to run this, since we're using YOLO

img_height = []
img_width = []
img_ar = [] # aspect_ratio

for i in train_imgs:
  img = cv2.imread(i)
  height, width, _ = img.shape
  ar = width / height

  img_height.append(width)
  img_width.append(height)
  img_ar.append(ar)

## merge with train df
img_df = pd.DataFrame({
    "filenames" : train_df['filenames'].unique().tolist(),
    "img_height" : img_height,
    "img_width" : img_width,
    "aspect_ratio": img_ar,
})

train_df = train_df.merge(img_df, how="left", on="filenames")
train_df.head()
# Out:
#   filenames                    bboxes categories  img_height  img_width  \
# 0     0.png  [6690, 3599, 7164, 3850]          0        7574       5625
# 1     0.png  [6772, 3386, 7039, 3546]          0        7574       5625
# 2     0.png  [6705, 3291, 7060, 3485]          0        7574       5625
# 3     0.png  [6230, 3442, 6597, 3647]          0        7574       5625
# 4     0.png    [5501, 790, 5552, 868]          0        7574       5625
#
#    aspect_ratio
# 0      1.346489
# 1      1.346489
# 2      1.346489
# 3      1.346489
# 4      1.346489

# %%
## test metadta to csv file

with open(test_metadata, 'r+') as j_files:
  j_list = list(j_files)
  
bboxes = []
filename = []
categories = []

for j_fle in j_list:
  rslt = json.loads(j_fle)

  bboxes.append(rslt['objects']['bbox'])
  filename.append(rslt['file_name'])
  categories.append(rslt['objects']['categories'])


test_df = pd.DataFrame(
    {
        "filenames": filename,
        "bboxes": bboxes,
        "categories": categories,
    })

test_df = test_df.explode(['bboxes', 'categories']).reset_index(drop=True)
test_df.head()
# Out:
#   filenames                bboxes categories
# 0     0.png  [100, 100, 110, 130]          0
# 1     0.png     [80, 80, 90, 100]          0
# 2     1.png  [100, 100, 110, 130]          0
# 3     1.png     [80, 80, 90, 100]          0
# 4    10.png  [100, 100, 110, 130]          0

# %%
# all the images doesn't have a unique size, 
## tghrtere will be a need for reshape

img_height = []
img_width = []
img_ar = [] # aspect_ratio

for i in test_imgs:
  img = cv2.imread(i)
  height, width, _ = img.shape
  ar = width / height

  img_height.append(width)
  img_width.append(height)
  img_ar.append(ar)

## merge with train df
img_df = pd.DataFrame({
    "filenames" : test_df['filenames'].unique().tolist(),
    "img_height" : img_height,
    "img_width" : img_width,
    "aspect_ratio": img_ar,
})

test_df = test_df.merge(img_df, how="left", on="filenames")
test_df.head()
# Out:
#   filenames                bboxes categories  img_height  img_width  \
# 0     0.png  [100, 100, 110, 130]          0        1676       1144
# 1     0.png     [80, 80, 90, 100]          0        1676       1144
# 2     1.png  [100, 100, 110, 130]          0        4000       4000
# 3     1.png     [80, 80, 90, 100]          0        4000       4000
# 4    10.png  [100, 100, 110, 130]          0        1959       1263
#
#    aspect_ratio
# 0      1.465035
# 1      1.465035
# 2      1.000000
# 3      1.000000
# 4      1.551069

# %%
def display_imgs_w_bbox(img_path, imgs_df):
  img = cv2.imread(img_path)
  file = img_path.split('/')[-1]
  fig, ax = plt.subplots(figsize=(25,25))
  ax.imshow(img);
  bboxes = imgs_df[imgs_df.filenames==file]['bboxes'].tolist()

  for b in bboxes:
    rect = patches.Rectangle((b[0], b[1]), b[2]-b[0], b[3]-b[1], linewidth=1, edgecolor='r', facecolor='none')
    ax.add_patch(rect)

  plt.show()

# %%
display_imgs_w_bbox(train_imgs[-1], train_df)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
## viewing all images with boundary boxes

def draw_boxes(img_path, imgs_df):
  img = cv2.imread(img_path)
  file = img_path.split('/')[-1]
  bboxes = imgs_df[imgs_df.filenames==file]['bboxes'].tolist()
  H, W, _ = img.shape

  for b in bboxes:
    x1 = b[0]
    y1 = b[1]
    x2 = b[2]
    x3 = b[3]
    x, y, w, h = pbx.convert_bbox((x1,y1,x2,x3), from_type='voc',
                                  to_type='yolo', image_size=(W, H))
    x1 = int((x-w/2)*W)
    y1 = int((y-h/2)*H)
    x2 = int((x+w/2)*W)
    y2 = int((y+h/2)*H)

    cv2.rectangle(img, (x1, y1), (x2, y2), (255,0, 0),5)

  return img

# %%
# animate
def create_animation(img_path, num):
  imgs = [draw_boxes(img_path[i], train_df) for i in range(num)]
  fig=plt.figure(figsize=(15, 20))
  im=plt.imshow(cv2.cvtColor(imgs[0],cv2.COLOR_BGR2RGB))
  plt.close()

  def animate_func(i):
    im.set_array(cv2.cvtColor(imgs[i],cv2.COLOR_BGR2RGB))
    return [im]

  return animation.FuncAnimation(fig, animate_func, frames=len(imgs), interval=1000//2)

# %%
# Create animation for 10 images
create_animation(train_imgs, 10)

# %%
# converting to yolov8 format 
# id,xmin,ymin,xmax,ymax
# 0.png,6690.0,3599.0,7164.0,3850.0
# [6690, 3599, 7164, 3850]

# %%
### YOLO data format. takes this:
## class x_centre y_centre width height.
# if no objects in image, no .txt file required for the image

# %%
## split validation and test files
filenames = train_df.filenames.unique().tolist()

train_idx = np.random.choice(len(filenames), round(len(filenames)*0.8), replace =False)
val_idx = np.array(list(set(range(len(filenames))) - set(train_idx)))

splt_val_imgs = [filenames[i] for i in list(val_idx)]
splt_train_imgs = [filenames[i] for i in list(train_idx)]

# %%
print (splt_val_imgs)
# Out:
# ['129.png', '4.png', '134.png', '7.png', '10.png', '139.png', '12.png', '13.png', '140.png', '141.png', '142.png', '17.png', '18.png', '145.png', '146.png', '147.png', '23.png', '25.png', '157.png', '31.png', '163.png', '42.png', '43.png', '174.png', '49.png', '177.png', '51.png', '52.png', '180.png', '184.png', '57.png', '58.png', '187.png', '190.png', '193.png', '201.png', '203.png', '208.png', '84.png', '87.png', '218.png', '97.png', '233.png', '107.png', '241.png', '115.png', '243.png', '244.png', '245.png', '247.png', '121.png']

# %%
## copy val imgs to another folder
val_dir = "/content/ship-detection/validation"
if not os.path.exists(val_dir):
  os.mkdir(val_dir)

for i in splt_val_imgs:
  copyfile(f"{train_dir}/{i}", f"{val_dir}/{i}")

# %%
# remove val images from train set
for i in splt_val_imgs:
  os.remove(f"{train_dir}/{i}")

# %%
len(os.listdir(val_dir))

# %%
# convert to yolo format
def convert_to_yolo(file_names: List, imgs_dir: os.PathLike, imgs_df:pd.DataFrame):

  for file in file_names:
    file_ = file.split('.')[0]
    img_path = os.path.join(imgs_dir, file)
    save_dir = os.path.join(imgs_dir, f"{file_}.txt")

    H, W, _ = cv2.imread(img_path).shape
    with open(save_dir, "w+") as fle:
      bboxes = imgs_df[imgs_df.filenames==file]['bboxes'].tolist()
      for bbox in bboxes:
        x1 = bbox[0]
        y1 = bbox[1]
        x2 = bbox[2]
        y2 = bbox[3]

        x, y, w, h = pbx.convert_bbox((x1, y1, x2, y2), from_type='voc',
                                      to_type='yolo', image_size=(W,H))
        
        fle.write(f"{0} {x} {y} {w} {h}\n")

# %%
## train conversion and val conversion

#convert_to_yolo(file_names: List, imgs_dir: os.PathLike, imgs_df:pd.DataFrame):
convert_to_yolo(splt_train_imgs, train_dir, train_df)
convert_to_yolo(splt_val_imgs, val_dir, train_df)

# %%
## test converiosn to yolo format
test_filenames = test_df.filenames.unique().tolist()
convert_to_yolo(test_filenames, test_dir, test_df)

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(draw_boxes("/content/ship-detection/train/197.png", train_df))
''' imgp = draw_boxes(train_imgs[0])
im=plt.imshow(cv2.cvtColor(imgp,cv2.COLOR_BGR2RGB)) '''

# %% [markdown]
# ### Training

# %%
## training

# %%
import yaml
train_yml = {
    "path" : "/content/ship-detection",
    "train": "train",
    "val" : "validation",
    "test": "test",
    "nc": 1,
    "names": ['ship']
}

with open("train.yml", "w+") as y_fle:
  yaml.dump(train_yml, y_fle, default_flow_style=True)

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
## TensorBoard: Start with 'tensorboard --logdir runs/detect/yolov8-v1-20epc-ship-detection', view at http://localhost:6006/

# %%
CFG = {
    'epochs': 5,
    'img_size' : 720,
    #'device': 'cpu',#'cuda',#
    'batch' : 8,
    'optimizer': 'Adam',
    'architecture' : 'yolov8',
}
# Out:
# ' run = wandb.init(\n    project = "satalite-ship-detection",\n    tags = [\'object-detection\', \'competition\', \'yolov8\'],\n    save_code = True,\n    config = CFG,\n) '

# %%
from ultralytics import YOLO
model = YOLO(model="yolov8n.pt")

trainer = model.train(
    data='train.yml',
    imgsz=CFG['img_size'],
    epochs=CFG['epochs'],
    #device=CFG['device'],# "cuda",
    batch = CFG["batch"],
    optimizer = CFG['optimizer'],
    name='yolov8-v1-5epc-ship-detection'
)
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8n.pt to yolov8n.pt...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 66.2MB/s]
# Ultralytics YOLOv8.0.74 🚀 Python-3.9.16 torch-2.0.0+cu118 CPU
# yolo/engine/trainer: task=detect, mode=train, model=yolov8n.pt, data=train.yml, epochs=5, patience=50, batch=8, imgsz=720, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=yolov8-v1-5epc-ship-detection, exist_ok=False, pretrained=False, optimizer=Adam, verbose=True, seed=0, deterministic=True, single_cls=False, image_weights=False, rect=False, cos_lr=False, close_mosaic=0, resume=False, amp=True, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, show=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, vid_stride=1, line_thickness=3, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, v5loader=False, tracker=botsort.yaml, save_dir=runs/detect/yolov8-v1-5epc-ship-detection
# Downloading https://ultralytics.com/assets/Arial.ttf to /root/.config/Ultralytics/Arial.ttf...
# 100%|██████████| 755k/755k [00:00<00:00, 25.7MB/s]
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.Conv                  [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.Conv                  [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.C2f                   [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.Conv                  [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.C2f                   [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.Conv                  [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.C2f                   [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.Conv                  [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.C2f                   [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.SPPF                  [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.Concat                [1]
#  12                  -1  1    148224  ultralytics.nn.modules.C2f                   [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.Concat                [1]
#  15                  -1  1     37248  ultralytics.nn.modules.C2f                   [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.Conv                  [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.Concat                [1]
#  18                  -1  1    123648  ultralytics.nn.modules.C2f                   [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.Conv                  [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.Concat                [1]
#  21                  -1  1    493056  ultralytics.nn.modules.C2f                   [384, 256, 1]
#  22        [15, 18, 21]  1    751507  ultralytics.nn.modules.Detect                [1, [64, 128, 256]]
# Model summary: 225 layers, 3011043 parameters, 3011027 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs/detect/yolov8-v1-5epc-ship-detection', view at http://localhost:6006/
# WARNING ⚠️ imgsz=[720] must be multiple of max stride 32, updating to [736]
# optimizer: Adam(lr=0.01) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias
# train: Scanning /content/ship-detection/train... 205 images, 0 backgrounds, 0 corrupt: 100%|██████████| 205/205 [00:24<00:00,  8.44it/s]
# train: New cache created: /content/ship-detection/train.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# val: Scanning /content/ship-detection/validation... 51 images, 0 backgrounds, 0 corrupt: 100%|██████████| 51/51 [00:02<00:00, 18.23it/s]
# val: New cache created: /content/ship-detection/validation.cache
# Plotting labels to runs/detect/yolov8-v1-5epc-ship-detection/labels.jpg...
# Image sizes 736 train, 736 val
# Using 0 dataloader workers
# Logging results to runs/detect/yolov8-v1-5epc-ship-detection
# Starting training for 5 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         1/5         0G      3.027      2.739      1.233        229        736: 100%|██████████| 26/26 [10:51<00:00, 25.05s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  25%|██▌       | 1/4 [00:15<00:47, 15.68s/it]WARNING ⚠️ NMS time limit 1.300s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  50%|█████     | 2/4 [00:41<00:43, 21.57s/it]WARNING ⚠️ NMS time limit 1.300s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [01:12<00:00, 18.19s/it]
#                    all         51       2235     0.0191     0.0922     0.0134    0.00536
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         2/5         0G      3.137      2.173       1.23        442        736: 100%|██████████| 26/26 [11:55<00:00, 27.54s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  25%|██▌       | 1/4 [00:15<00:45, 15.16s/it]WARNING ⚠️ NMS time limit 1.300s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  50%|█████     | 2/4 [00:40<00:42, 21.30s/it]WARNING ⚠️ NMS time limit 1.300s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [01:11<00:00, 17.98s/it]
#                    all         51       2235     0.0199     0.0577     0.0102    0.00395
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         3/5         0G      2.964       2.02      1.208        107        736: 100%|██████████| 26/26 [12:01<00:00, 27.75s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):   0%|          | 0/4 [00:00<?, ?it/s]WARNING ⚠️ NMS time limit 1.300s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  25%|██▌       | 1/4 [00:15<00:46, 15.40s/it]WARNING ⚠️ NMS time limit 1.300s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  50%|█████     | 2/4 [00:39<00:41, 20.53s/it]WARNING ⚠️ NMS time limit 1.300s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [01:11<00:00, 17.83s/it]
#                    all         51       2235      0.103     0.0667     0.0321     0.0102
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         4/5         0G      2.891      1.829      1.159        562        736: 100%|██████████| 26/26 [14:09<00:00, 32.68s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  25%|██▌       | 1/4 [00:15<00:46, 15.51s/it]WARNING ⚠️ NMS time limit 1.300s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  50%|█████     | 2/4 [00:40<00:42, 21.31s/it]WARNING ⚠️ NMS time limit 1.300s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [01:11<00:00, 17.92s/it]
#                    all         51       2235      0.183     0.0828     0.0527     0.0187
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         5/5         0G      2.741      1.706      1.101        170        736: 100%|██████████| 26/26 [14:13<00:00, 32.83s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [01:19<00:00, 19.95s/it]
#                    all         51       2235       0.36      0.187      0.133     0.0344
#
# 5 epochs completed in 1.157 hours.
# Optimizer stripped from runs/detect/yolov8-v1-5epc-ship-detection/weights/last.pt, 6.2MB
# Optimizer stripped from runs/detect/yolov8-v1-5epc-ship-detection/weights/best.pt, 6.2MB
#
# Validating runs/detect/yolov8-v1-5epc-ship-detection/weights/best.pt...
# Ultralytics YOLOv8.0.74 🚀 Python-3.9.16 torch-2.0.0+cu118 CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-18-196704124c25> in <cell line: 4>()
#       2 model = YOLO(model="yolov8n.pt", task="detect")
#       3
# ----> 4 trainer = model.train(
#       5     data='train.yml',
#       6     imgsz=CFG['img_size'],
#
# /usr/local/lib/python3.9/dist-packages/ultralytics/yolo/engine/model.py in train(self, **kwargs)
#     365             self.model = self.trainer.model
#     366         self.trainer.hub_session = self.session  # attach optional HUB session
# --> 367         self.trainer.train()
#     368         # update model and cfg after training
#     369         if RANK in (-1, 0):
#
# /usr/local/lib/python3.9/dist-packages/ultralytics/yolo/engine/trainer.py in train(self)
#     188                 ddp_cleanup(self, str(file))
#     189         else:
# --> 190             self._do_train(world_size)
#     191
#     192     def _setup_ddp(self, world_size):
#
# /usr/local/lib/python3.9/dist-packages/ultralytics/yolo/engine/trainer.py in _do_train(self, world_size)
#     385             LOGGER.info(f'\n{epoch - self.start_epoch + 1} epochs completed in '
#     386                         f'{(time.time() - self.train_time_start) / 3600:.3f} hours.')
# --> 387             self.final_eval()
#     388             if self.args.plots:
#     389                 self.plot_metrics()
#
# /usr/local/lib/python3.9/dist-packages/ultralytics/yolo/engine/trainer.py in final_eval(self)
#     521                 if f is self.best:
#     522                     LOGGER.info(f'\nValidating {f}...')
# --> 523                     self.metrics = self.validator(model=f)
#     524                     self.metrics.pop('fitness', None)
#     525                     self.run_callbacks('on_fit_epoch_end')
#
# /usr/local/lib/python3.9/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     113     def decorate_context(*args, **kwargs):
#     114         with ctx_factory():
# --> 115             return func(*args, **kwargs)
#     116
#     117     return decorate_context
#
# /usr/local/lib/python3.9/dist-packages/ultralytics/yolo/engine/validator.py in __call__(self, trainer, model)
#     127                 self.data = check_cls_dataset(self.args.data)
#     128             else:
# --> 129                 raise FileNotFoundError(emojis(f"Dataset '{self.args.data}' for task={self.args.task} not found ❌"))
#     130
#     131             if self.device.type == 'cpu':
#
# FileNotFoundError: Dataset 'train.yml' for task=detect not found ❌

# %%
# !cp -r "/content/runs" "/content/gdrive/MyDrive/Models"

# %% [markdown]
# ### Validation step

# %%
vrelts = model.val()

# %%
# Make prediciton with best model
from ultralytics import YOLO

best_model = YOLO("/content/gdrive/MyDrive/Models/runs/detect/yolov8-v1-5epc-ship-detection/weights/best.pt")
preds = best_model.predict(
    conf=0.1, source = "/content/ship-detection/test")
# Out:
# image 1/385 /content/ship-detection/test/0.png: 480x736 300 ships, 276.3ms
# image 2/385 /content/ship-detection/test/1.png: 576x736 43 ships, 172.9ms
# image 3/385 /content/ship-detection/test/10.png: 736x736 300 ships, 220.4ms
# image 4/385 /content/ship-detection/test/100.png: 736x608 199 ships, 181.6ms
# image 5/385 /content/ship-detection/test/101.png: 736x640 28 ships, 199.1ms
# image 6/385 /content/ship-detection/test/102.png: 576x736 300 ships, 155.1ms
# image 7/385 /content/ship-detection/test/103.png: 736x736 300 ships, 217.0ms
# image 8/385 /content/ship-detection/test/104.png: 736x736 300 ships, 208.1ms
# image 9/385 /content/ship-detection/test/105.png: 704x736 300 ships, 204.3ms
# image 10/385 /content/ship-detection/test/106.png: 736x736 300 ships, 209.5ms
# image 11/385 /content/ship-detection/test/107.png: 224x736 300 ships, 78.2ms
# image 12/385 /content/ship-detection/test/108.png: 736x384 300 ships, 115.0ms
# image 13/385 /content/ship-detection/test/109.png: 736x672 300 ships, 191.9ms
# image 14/385 /content/ship-detection/test/11.png: 736x448 300 ships, 133.9ms
# image 15/385 /content/ship-detection/test/110.png: 736x736 300 ships, 203.8ms
# image 16/385 /content/ship-detection/test/111.png: 576x736 300 ships, 160.8ms
# image 17/385 /content/ship-detection/test/112.png: 736x704 300 ships, 198.3ms
# image 18/385 /content/ship-detection/test/113.png: 704x736 300 ships, 190.2ms
# image 19/385 /content/ship-detection/test/114.png: 736x512 300 ships, 143.4ms
# image 20/385 /content/ship-detection/test/115.png: 736x736 113 ships, 202.1ms
# image 21/385 /content/ship-detection/test/116.png: 640x736 300 ships, 181.0ms
# image 22/385 /content/ship-detection/test/117.png: 736x736 222 ships, 196.0ms
# image 23/385 /content/ship-detection/test/118.png: 736x608 258 ships, 171.8ms
# image 24/385 /content/ship-detection/test/119.png: 736x672 46 ships, 286.4ms
# image 25/385 /content/ship-detection/test/12.png: 576x736 300 ships, 262.5ms
# image 26/385 /content/ship-detection/test/120.png: 576x736 300 ships, 262.8ms
# image 27/385 /content/ship-detection/test/121.png: 736x640 46 ships, 298.7ms
# image 28/385 /content/ship-detection/test/122.png: 736x352 300 ships, 177.5ms
# image 29/385 /content/ship-detection/test/123.png: 736x704 300 ships, 317.9ms
# image 30/385 /content/ship-detection/test/124.png: 736x736 300 ships, 321.4ms
# image 31/385 /content/ship-detection/test/125.png: 736x736 300 ships, 343.7ms
# image 32/385 /content/ship-detection/test/126.png: 736x704 300 ships, 302.4ms
# image 33/385 /content/ship-detection/test/127.png: 416x736 190 ships, 188.1ms
# image 34/385 /content/ship-detection/test/128.png: 736x736 300 ships, 340.5ms
# image 35/385 /content/ship-detection/test/129.png: 736x352 300 ships, 157.0ms
# image 36/385 /content/ship-detection/test/13.png: 736x736 300 ships, 213.2ms
# image 37/385 /content/ship-detection/test/130.png: 736x640 300 ships, 170.5ms
# image 38/385 /content/ship-detection/test/131.png: 672x736 (no detections), 190.1ms
# image 39/385 /content/ship-detection/test/132.png: 736x736 300 ships, 189.5ms
# image 40/385 /content/ship-detection/test/133.png: 544x736 300 ships, 161.2ms
# image 41/385 /content/ship-detection/test/134.png: 736x352 300 ships, 100.2ms
# image 42/385 /content/ship-detection/test/135.png: 736x544 300 ships, 158.7ms
# image 43/385 /content/ship-detection/test/136.png: 736x576 300 ships, 153.6ms
# image 44/385 /content/ship-detection/test/137.png: 384x736 300 ships, 108.2ms
# image 45/385 /content/ship-detection/test/138.png: 704x736 300 ships, 189.9ms
# image 46/385 /content/ship-detection/test/139.png: 256x736 300 ships, 74.0ms
# image 47/385 /content/ship-detection/test/14.png: 736x736 300 ships, 205.0ms
# image 48/385 /content/ship-detection/test/140.png: 736x736 300 ships, 197.0ms
# image 49/385 /content/ship-detection/test/141.png: 576x736 51 ships, 151.2ms
# image 50/385 /content/ship-detection/test/142.png: 736x640 300 ships, 176.6ms
# image 51/385 /content/ship-detection/test/143.png: 320x736 300 ships, 92.0ms
# image 52/385 /content/ship-detection/test/144.png: 736x512 300 ships, 136.9ms
# image 53/385 /content/ship-detection/test/145.png: 736x704 300 ships, 200.1ms
# image 54/385 /content/ship-detection/test/146.png: 736x736 300 ships, 200.8ms
# image 55/385 /content/ship-detection/test/147.png: 736x736 300 ships, 212.0ms
# image 56/385 /content/ship-detection/test/148.png: 480x736 300 ships, 140.9ms
# image 57/385 /content/ship-detection/test/149.png: 736x640 300 ships, 167.6ms
# image 58/385 /content/ship-detection/test/15.png: 480x736 300 ships, 140.4ms
# image 59/385 /content/ship-detection/test/150.png: 736x736 300 ships, 200.8ms
# image 60/385 /content/ship-detection/test/151.png: 576x736 300 ships, 162.2ms
# image 61/385 /content/ship-detection/test/152.png: 736x512 300 ships, 146.7ms
# image 62/385 /content/ship-detection/test/153.png: 544x736 300 ships, 173.5ms
# image 63/385 /content/ship-detection/test/154.png: 736x544 300 ships, 166.6ms
# image 64/385 /content/ship-detection/test/155.png: 736x512 300 ships, 153.6ms
# image 65/385 /content/ship-detection/test/156.png: 576x736 19 ships, 201.0ms
# image 66/385 /content/ship-detection/test/157.png: 736x736 300 ships, 336.4ms
# image 67/385 /content/ship-detection/test/158.png: 448x736 8 ships, 226.9ms
# image 68/385 /content/ship-detection/test/159.png: 608x736 300 ships, 270.8ms
# image 69/385 /content/ship-detection/test/16.png: 736x736 300 ships, 345.2ms
# image 70/385 /content/ship-detection/test/160.png: 736x416 300 ships, 207.2ms
# image 71/385 /content/ship-detection/test/161.png: 480x736 300 ships, 219.5ms
# image 72/385 /content/ship-detection/test/162.png: 736x736 94 ships, 339.6ms
# image 73/385 /content/ship-detection/test/163.png: 704x736 300 ships, 300.4ms
# image 74/385 /content/ship-detection/test/164.png: 736x736 9 ships, 318.9ms
# image 75/385 /content/ship-detection/test/165.png: 256x736 300 ships, 120.0ms
# image 76/385 /content/ship-detection/test/166.png: 736x448 201 ships, 195.9ms
# image 77/385 /content/ship-detection/test/167.png: 736x416 300 ships, 200.2ms
# image 78/385 /content/ship-detection/test/168.png: 736x736 300 ships, 310.7ms
# image 79/385 /content/ship-detection/test/169.png: 736x736 222 ships, 329.7ms
# image 80/385 /content/ship-detection/test/17.png: 384x736 300 ships, 103.9ms
# image 81/385 /content/ship-detection/test/170.png: 736x736 205 ships, 196.5ms
# image 82/385 /content/ship-detection/test/171.png: 576x736 300 ships, 155.7ms
# image 83/385 /content/ship-detection/test/172.png: 640x736 300 ships, 169.5ms
# image 84/385 /content/ship-detection/test/173.png: 736x288 300 ships, 89.6ms
# image 85/385 /content/ship-detection/test/174.png: 736x736 300 ships, 197.5ms
# image 86/385 /content/ship-detection/test/175.png: 512x736 300 ships, 149.9ms
# image 87/385 /content/ship-detection/test/176.png: 384x736 300 ships, 103.8ms
# image 88/385 /content/ship-detection/test/177.png: 736x736 28 ships, 201.9ms
# image 89/385 /content/ship-detection/test/178.png: 736x352 300 ships, 108.7ms
# image 90/385 /content/ship-detection/test/179.png: 736x736 300 ships, 195.9ms
# image 91/385 /content/ship-detection/test/18.png: 576x736 29 ships, 157.0ms
# image 92/385 /content/ship-detection/test/180.png: 704x736 300 ships, 193.1ms
# image 93/385 /content/ship-detection/test/181.png: 352x736 300 ships, 101.7ms
# image 94/385 /content/ship-detection/test/182.png: 736x736 300 ships, 194.6ms
# image 95/385 /content/ship-detection/test/183.png: 576x736 300 ships, 162.3ms
# image 96/385 /content/ship-detection/test/184.png: 736x608 300 ships, 163.0ms
# image 97/385 /content/ship-detection/test/185.png: 736x736 300 ships, 191.4ms
# image 98/385 /content/ship-detection/test/186.png: 512x736 300 ships, 140.1ms
# image 99/385 /content/ship-detection/test/187.png: 512x736 300 ships, 140.8ms
# image 100/385 /content/ship-detection/test/188.png: 544x736 300 ships, 157.0ms
# image 101/385 /content/ship-detection/test/189.png: 448x736 300 ships, 137.0ms
# image 102/385 /content/ship-detection/test/19.png: 736x736 300 ships, 192.3ms
# image 103/385 /content/ship-detection/test/190.png: 736x640 1 ship, 171.0ms
# image 104/385 /content/ship-detection/test/191.png: 384x736 300 ships, 101.3ms
# image 105/385 /content/ship-detection/test/192.png: 576x736 300 ships, 156.2ms
# image 106/385 /content/ship-detection/test/193.png: 608x736 300 ships, 169.9ms
# image 107/385 /content/ship-detection/test/194.png: 192x736 300 ships, 64.2ms
# image 108/385 /content/ship-detection/test/195.png: 736x736 (no detections), 333.9ms
# image 109/385 /content/ship-detection/test/196.png: 512x736 300 ships, 247.5ms
# image 110/385 /content/ship-detection/test/197.png: 736x320 106 ships, 168.2ms
# image 111/385 /content/ship-detection/test/198.png: 64x736 300 ships, 43.4ms
# image 112/385 /content/ship-detection/test/199.png: 608x736 300 ships, 260.9ms
# image 113/385 /content/ship-detection/test/2.png: 224x736 300 ships, 116.3ms
# image 114/385 /content/ship-detection/test/20.png: 736x736 76 ships, 333.4ms
# image 115/385 /content/ship-detection/test/200.png: 736x608 300 ships, 269.1ms
# image 116/385 /content/ship-detection/test/201.png: 416x736 300 ships, 187.6ms
# image 117/385 /content/ship-detection/test/202.png: 608x736 181 ships, 268.8ms
# image 118/385 /content/ship-detection/test/203.png: 736x480 300 ships, 226.2ms
# image 119/385 /content/ship-detection/test/204.png: 512x736 300 ships, 225.0ms
# image 120/385 /content/ship-detection/test/205.png: 512x736 300 ships, 234.6ms
# image 121/385 /content/ship-detection/test/206.png: 640x736 300 ships, 281.9ms
# image 122/385 /content/ship-detection/test/207.png: 512x736 300 ships, 226.2ms
# image 123/385 /content/ship-detection/test/208.png: 192x736 300 ships, 112.4ms
# image 124/385 /content/ship-detection/test/209.png: 736x608 300 ships, 169.9ms
# image 125/385 /content/ship-detection/test/21.png: 224x736 300 ships, 66.4ms
# image 126/385 /content/ship-detection/test/210.png: 736x640 300 ships, 174.2ms
# image 127/385 /content/ship-detection/test/211.png: 736x352 208 ships, 96.4ms
# image 128/385 /content/ship-detection/test/212.png: 736x640 11 ships, 170.6ms
# image 129/385 /content/ship-detection/test/213.png: 512x736 173 ships, 142.7ms
# image 130/385 /content/ship-detection/test/214.png: 736x736 300 ships, 214.9ms
# image 131/385 /content/ship-detection/test/215.png: 512x736 300 ships, 141.1ms
# image 132/385 /content/ship-detection/test/216.png: 480x736 300 ships, 133.0ms
# image 133/385 /content/ship-detection/test/217.png: 736x608 300 ships, 164.6ms
# image 134/385 /content/ship-detection/test/218.png: 160x736 296 ships, 60.9ms
# image 135/385 /content/ship-detection/test/219.png: 736x704 300 ships, 199.5ms
# image 136/385 /content/ship-detection/test/22.png: 704x736 113 ships, 194.3ms
# image 137/385 /content/ship-detection/test/220.png: 736x736 300 ships, 207.9ms
# image 138/385 /content/ship-detection/test/221.png: 544x736 300 ships, 141.8ms
# image 139/385 /content/ship-detection/test/222.png: 736x608 300 ships, 171.0ms
# image 140/385 /content/ship-detection/test/223.png: 512x736 300 ships, 147.9ms
# image 141/385 /content/ship-detection/test/224.png: 736x736 5 ships, 193.1ms
# image 142/385 /content/ship-detection/test/225.png: 736x736 16 ships, 225.7ms
# image 143/385 /content/ship-detection/test/226.png: 704x736 300 ships, 209.0ms
# image 144/385 /content/ship-detection/test/227.png: 736x608 242 ships, 187.0ms
# image 145/385 /content/ship-detection/test/228.png: 384x736 300 ships, 125.2ms
# image 146/385 /content/ship-detection/test/229.png: 320x736 300 ships, 94.9ms
# image 147/385 /content/ship-detection/test/23.png: 736x576 300 ships, 163.8ms
# image 148/385 /content/ship-detection/test/230.png: 736x576 300 ships, 159.4ms
# image 149/385 /content/ship-detection/test/231.png: 736x640 28 ships, 174.6ms
# image 150/385 /content/ship-detection/test/232.png: 736x736 300 ships, 213.8ms
# image 151/385 /content/ship-detection/test/233.png: 736x640 300 ships, 187.8ms
# image 152/385 /content/ship-detection/test/234.png: 736x64 94 ships, 34.1ms
# image 153/385 /content/ship-detection/test/235.png: 512x736 300 ships, 145.2ms
# image 154/385 /content/ship-detection/test/236.png: 736x704 300 ships, 240.1ms
# image 155/385 /content/ship-detection/test/237.png: 576x736 300 ships, 263.1ms
# image 156/385 /content/ship-detection/test/238.png: 736x480 300 ships, 217.6ms
# image 157/385 /content/ship-detection/test/239.png: 672x736 300 ships, 313.7ms
# image 158/385 /content/ship-detection/test/24.png: 736x352 171 ships, 168.6ms
# image 159/385 /content/ship-detection/test/240.png: 736x384 281 ships, 181.5ms
# image 160/385 /content/ship-detection/test/241.png: 640x736 300 ships, 287.1ms
# image 161/385 /content/ship-detection/test/242.png: 736x736 300 ships, 326.5ms
# image 162/385 /content/ship-detection/test/243.png: 384x736 300 ships, 176.3ms
# image 163/385 /content/ship-detection/test/244.png: 640x736 300 ships, 279.5ms
# image 164/385 /content/ship-detection/test/245.png: 736x608 114 ships, 272.7ms
# image 165/385 /content/ship-detection/test/246.png: 736x640 3 ships, 271.2ms
# image 166/385 /content/ship-detection/test/247.png: 736x736 53 ships, 314.1ms
# image 167/385 /content/ship-detection/test/248.png: 736x736 110 ships, 223.6ms
# image 168/385 /content/ship-detection/test/249.png: 736x576 300 ships, 155.6ms
# image 169/385 /content/ship-detection/test/25.png: 672x736 300 ships, 192.7ms
# image 170/385 /content/ship-detection/test/250.png: 576x736 300 ships, 151.3ms
# image 171/385 /content/ship-detection/test/251.png: 480x736 300 ships, 140.6ms
# image 172/385 /content/ship-detection/test/252.png: 512x736 300 ships, 163.4ms
# image 173/385 /content/ship-detection/test/253.png: 576x736 1 ship, 154.1ms
# image 174/385 /content/ship-detection/test/254.png: 576x736 (no detections), 163.9ms
# image 175/385 /content/ship-detection/test/255.png: 736x736 240 ships, 206.6ms
# image 176/385 /content/ship-detection/test/256.png: 576x736 17 ships, 157.8ms
# image 177/385 /content/ship-detection/test/257.png: 736x512 300 ships, 159.9ms
# image 178/385 /content/ship-detection/test/258.png: 512x736 300 ships, 137.2ms
# image 179/385 /content/ship-detection/test/259.png: 480x736 300 ships, 154.2ms
# image 180/385 /content/ship-detection/test/26.png: 736x736 300 ships, 210.4ms
# image 181/385 /content/ship-detection/test/260.png: 480x736 300 ships, 136.2ms
# image 182/385 /content/ship-detection/test/261.png: 736x736 300 ships, 199.0ms
# image 183/385 /content/ship-detection/test/262.png: 736x736 300 ships, 198.2ms
# image 184/385 /content/ship-detection/test/263.png: 736x384 300 ships, 106.2ms
# image 185/385 /content/ship-detection/test/264.png: 736x640 300 ships, 184.4ms
# image 186/385 /content/ship-detection/test/265.png: 704x736 300 ships, 201.3ms
# image 187/385 /content/ship-detection/test/266.png: 128x736 300 ships, 76.5ms
# image 188/385 /content/ship-detection/test/267.png: 736x736 300 ships, 321.3ms
# image 189/385 /content/ship-detection/test/268.png: 672x736 300 ships, 281.5ms
# image 190/385 /content/ship-detection/test/269.png: 672x736 300 ships, 279.8ms
# image 191/385 /content/ship-detection/test/27.png: 608x736 152 ships, 252.0ms
# image 192/385 /content/ship-detection/test/270.png: 736x544 300 ships, 251.8ms
# image 193/385 /content/ship-detection/test/271.png: 736x640 300 ships, 295.0ms
# image 194/385 /content/ship-detection/test/272.png: 736x384 300 ships, 179.4ms
# image 195/385 /content/ship-detection/test/273.png: 544x736 300 ships, 148.8ms
# image 196/385 /content/ship-detection/test/274.png: 448x736 300 ships, 127.0ms
# image 197/385 /content/ship-detection/test/275.png: 736x736 300 ships, 198.6ms
# image 198/385 /content/ship-detection/test/276.png: 736x544 300 ships, 152.1ms
# image 199/385 /content/ship-detection/test/277.png: 544x736 300 ships, 150.1ms
# image 200/385 /content/ship-detection/test/278.png: 64x736 152 ships, 24.8ms
# image 201/385 /content/ship-detection/test/279.png: 128x736 228 ships, 40.2ms
# image 202/385 /content/ship-detection/test/28.png: 736x736 300 ships, 202.5ms
# image 203/385 /content/ship-detection/test/280.png: 736x416 246 ships, 124.0ms
# image 204/385 /content/ship-detection/test/281.png: 736x640 39 ships, 171.7ms
# image 205/385 /content/ship-detection/test/282.png: 576x736 23 ships, 149.9ms
# image 206/385 /content/ship-detection/test/283.png: 448x736 300 ships, 142.8ms
# image 207/385 /content/ship-detection/test/284.png: 512x736 300 ships, 137.8ms
# image 208/385 /content/ship-detection/test/285.png: 704x736 300 ships, 192.8ms
# image 209/385 /content/ship-detection/test/286.png: 512x736 300 ships, 143.1ms
# image 210/385 /content/ship-detection/test/287.png: 736x736 300 ships, 202.1ms
# image 211/385 /content/ship-detection/test/288.png: 576x736 300 ships, 159.5ms
# image 212/385 /content/ship-detection/test/289.png: 576x736 300 ships, 156.0ms
# image 213/385 /content/ship-detection/test/29.png: 704x736 300 ships, 183.8ms
# image 214/385 /content/ship-detection/test/290.png: 512x736 300 ships, 141.8ms
# image 215/385 /content/ship-detection/test/291.png: 736x736 300 ships, 189.0ms
# image 216/385 /content/ship-detection/test/292.png: 384x736 300 ships, 105.7ms
# image 217/385 /content/ship-detection/test/293.png: 544x736 300 ships, 149.0ms
# image 218/385 /content/ship-detection/test/294.png: 352x736 233 ships, 103.9ms
# image 219/385 /content/ship-detection/test/295.png: 416x736 179 ships, 165.4ms
# image 220/385 /content/ship-detection/test/296.png: 736x448 169 ships, 212.9ms
# image 221/385 /content/ship-detection/test/297.png: 736x736 105 ships, 317.1ms
# image 222/385 /content/ship-detection/test/298.png: 544x736 208 ships, 258.1ms
# image 223/385 /content/ship-detection/test/299.png: 576x736 300 ships, 260.0ms
# image 224/385 /content/ship-detection/test/3.png: 736x544 300 ships, 248.7ms
# image 225/385 /content/ship-detection/test/30.png: 576x736 257 ships, 261.2ms
# image 226/385 /content/ship-detection/test/300.png: 736x480 300 ships, 219.0ms
# image 227/385 /content/ship-detection/test/301.png: 736x736 7 ships, 318.8ms
# image 228/385 /content/ship-detection/test/302.png: 736x736 300 ships, 319.9ms
# image 229/385 /content/ship-detection/test/303.png: 736x736 236 ships, 315.2ms
# image 230/385 /content/ship-detection/test/304.png: 736x608 300 ships, 265.0ms

# %%
sort_test_img = [f"/content/ship-detection/test/{i}.png" for i in range(386)]

test_preds = pd.DataFrame(columns=range(6))
for i in range(len(preds)):
    arri = pd.DataFrame(preds[i].boxes.boxes.cpu()).astype(float)
    path = sort_test_img[i]
    file = path.split('/')[-1]
    arri = arri.assign(file=file)
    arri = arri.assign(i=i)
    test_preds = pd.concat([test_preds,arri],axis=0)
test_preds.columns = ['xmin','ymin','xmax','ymax','confidence','class','id','i']
display(test_preds)

# %%
test_preds = test_preds[["id","xmin","ymin","xmax","ymax","confidence"]].reset_index(drop=True)

# %%
sample_sub = pd.DataFrame([i.split('/')[-1] for i in test_imgs],columns=["id"]).reset_index(drop=True)
sample_sub["label"] = "0 0 0 10 10"

# %%
# Convert detections to string format
import tqdm
for i in tqdm.tqdm(range(len(sample_sub))):
    detections = []
    idd = sample_sub.loc[i,'id']
    df = test_preds[test_preds['id']==idd]
#     print(len(df))
    for i, row in df.iterrows():
        detection_str = f"{row['confidence']} {int(row['xmin'])} {int(row['ymin'])} {int(row['xmax'])} {int(row['ymax'])}"
        detections.append(detection_str)
    detections_str = ', '.join(detections)
    idx = list(sample_sub[sample_sub['id']==idd].index)
    if len(df)>0:
        sample_sub.loc[idx,"label"] = detections_str
#     break
